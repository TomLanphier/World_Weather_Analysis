# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

import requests
from config import weather_api_key

import time
from datetime import datetime

from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_current_desc = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_current_desc})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port lincoln
# Processing Record 2 of Set 1 | zlobin
# Processing Record 3 of Set 1 | tura
# Processing Record 4 of Set 1 | byron bay
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | east london
# Processing Record 9 of Set 1 | georgetown
# Processing Record 10 of Set 1 | elko
# Processing Record 11 of Set 1 | saldanha
# Processing Record 12 of Set 1 | srednekolymsk
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | igarka
# Processing Record 15 of Set 1 | bismil
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | lagoa
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 1 | coihaique
# Processing Record 22 of Set 1 | villanueva
# Processing Record 23 of Set 1 | yellowknife
# Processing Record 24 of Set 1 | dali
# Processing Record 25 of Set 1 | saskylakh
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | el pinon
# Processing Record 28 of Set 1 | bethel
# Processing Record 29 of Set 1 | makinsk
# Processing Record 30 of Set 1 | faanui
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | thompson
# Processing Record 33 of Set 1 | dalvik
# Processing Record 34 of Set 1 | noumea
# Processing Record 35 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 36 of Set 1 | san patricio
# Processing Record 37 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 1 | san rafael
# Processing Record 39 of Set 1 | avarua
# Processing Record 40 of Set 1 | najran
# Processing Record 41 of Set 1 | esperance
# Processing Record 42 of Set 1 | marrakesh
# Processing Record 43 of Set 1 | westlock
# Processing Record 44 of Set 1 | hobart
# Processing Record 45 of Set 1 | vostok
# Processing Record 46 of Set 1 | tanout
# Processing Record 47 of Set 1 | kapaa
# Processing Record 48 of Set 1 | ixtapa
# Processing Record 49 of Set 1 | tabatinga
# Processing Record 50 of Set 1 | bonfim
# Processing Record 1 of Set 2 | itarema
# Processing Record 2 of Set 2 | shenjiamen
# Processing Record 3 of Set 2 | freeport
# Processing Record 4 of Set 2 | okhotsk
# Processing Record 5 of Set 2 | yantai
# Processing Record 6 of Set 2 | omsukchan
# Processing Record 7 of Set 2 | sumbe
# Processing Record 8 of Set 2 | carlos antonio lopez
# Processing Record 9 of Set 2 | payyannur
# Processing Record 10 of Set 2 | bilma
# Processing Record 11 of Set 2 | ostrovnoy
# Processing Record 12 of Set 2 | rikitea
# Processing Record 13 of Set 2 | butaritari
# Processing Record 14 of Set 2 | yenagoa
# Processing Record 15 of Set 2 | muros
# Processing Record 16 of Set 2 | chuy
# Processing Record 17 of Set 2 | barrow
# Processing Record 18 of Set 2 | qaanaaq
# Processing Record 19 of Set 2 | olafsvik
# Processing Record 20 of Set 2 | susanville
# Processing Record 21 of Set 2 | pevek
# Processing Record 22 of Set 2 | mahadday weyne
# City not found. Skipping...
# Processing Record 23 of Set 2 | udachnyy
# Processing Record 24 of Set 2 | cesvaine
# Processing Record 25 of Set 2 | werdau
# Processing Record 26 of Set 2 | severo-kurilsk
# Processing Record 27 of Set 2 | kavieng
# Processing Record 28 of Set 2 | mar del plata
# Processing Record 29 of Set 2 | vaini
# Processing Record 30 of Set 2 | opotiki
# Processing Record 31 of Set 2 | castro
# Processing Record 32 of Set 2 | albany
# Processing Record 33 of Set 2 | khandyga
# Processing Record 34 of Set 2 | san cristobal
# Processing Record 35 of Set 2 | torbay
# Processing Record 36 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 2 | ribeira grande
# Processing Record 38 of Set 2 | hithadhoo
# Processing Record 39 of Set 2 | khanpur
# Processing Record 40 of Set 2 | floro
# Processing Record 41 of Set 2 | new norfolk
# Processing Record 42 of Set 2 | santa marta
# Processing Record 43 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 2 | port alfred
# Processing Record 45 of Set 2 | umea
# Processing Record 46 of Set 2 | bredasdorp
# Processing Record 47 of Set 2 | savelugu
# Processing Record 48 of Set 2 | fortuna
# Processing Record 49 of Set 2 | kemin
# Processing Record 50 of Set 2 | bereda
# Processing Record 1 of Set 3 | port elizabeth
# Processing Record 2 of Set 3 | daura
# Processing Record 3 of Set 3 | veraval
# Processing Record 4 of Set 3 | roald
# Processing Record 5 of Set 3 | lincoln
# Processing Record 6 of Set 3 | rio tercero
# Processing Record 7 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 8 of Set 3 | yar-sale
# Processing Record 9 of Set 3 | acapulco
# Processing Record 10 of Set 3 | dikson
# Processing Record 11 of Set 3 | vicksburg
# Processing Record 12 of Set 3 | saint-philippe
# Processing Record 13 of Set 3 | neiafu
# Processing Record 14 of Set 3 | hede
# Processing Record 15 of Set 3 | ossora
# Processing Record 16 of Set 3 | tongren
# Processing Record 17 of Set 3 | khatanga
# Processing Record 18 of Set 3 | kuznechnoye
# Processing Record 19 of Set 3 | isangel
# Processing Record 20 of Set 3 | rocha
# Processing Record 21 of Set 3 | turukhansk
# Processing Record 22 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 3 | chai badan
# Processing Record 24 of Set 3 | provideniya
# Processing Record 25 of Set 3 | san luis
# Processing Record 26 of Set 3 | saint-georges
# Processing Record 27 of Set 3 | batagay-alyta
# Processing Record 28 of Set 3 | terney
# Processing Record 29 of Set 3 | qaqortoq
# Processing Record 30 of Set 3 | bangsund
# Processing Record 31 of Set 3 | tiksi
# Processing Record 32 of Set 3 | udalguri
# Processing Record 33 of Set 3 | norman wells
# Processing Record 34 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 3 | tasiilaq
# Processing Record 36 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 3 | flinders
# Processing Record 38 of Set 3 | saint george
# Processing Record 39 of Set 3 | hamilton
# Processing Record 40 of Set 3 | esqueda
# Processing Record 41 of Set 3 | santa catarina de tepehuanes
# Processing Record 42 of Set 3 | hobyo
# Processing Record 43 of Set 3 | cockburn harbour
# City not found. Skipping...
# Processing Record 44 of Set 3 | awjilah
# Processing Record 45 of Set 3 | whitehorse
# Processing Record 46 of Set 3 | port blair
# Processing Record 47 of Set 3 | puerto ayora
# Processing Record 48 of Set 3 | sitka
# Processing Record 49 of Set 3 | nelson bay
# Processing Record 50 of Set 3 | tayga
# Processing Record 1 of Set 4 | nanortalik
# Processing Record 2 of Set 4 | carnarvon
# Processing Record 3 of Set 4 | ponta do sol
# Processing Record 4 of Set 4 | longyearbyen
# Processing Record 5 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 6 of Set 4 | luanshya
# Processing Record 7 of Set 4 | bodaybo
# Processing Record 8 of Set 4 | elektrogorsk
# Processing Record 9 of Set 4 | ahipara
# Processing Record 10 of Set 4 | sala consilina
# Processing Record 11 of Set 4 | vila velha
# Processing Record 12 of Set 4 | buraydah
# Processing Record 13 of Set 4 | evensk
# Processing Record 14 of Set 4 | yarada
# Processing Record 15 of Set 4 | airai
# Processing Record 16 of Set 4 | grand gaube
# Processing Record 17 of Set 4 | wembley
# Processing Record 18 of Set 4 | nikolskoye
# Processing Record 19 of Set 4 | sinnamary
# Processing Record 20 of Set 4 | cheyenne
# Processing Record 21 of Set 4 | neryungri
# Processing Record 22 of Set 4 | norsup
# Processing Record 23 of Set 4 | nouadhibou
# Processing Record 24 of Set 4 | redmond
# Processing Record 25 of Set 4 | yeppoon
# Processing Record 26 of Set 4 | padang
# Processing Record 27 of Set 4 | taltal
# Processing Record 28 of Set 4 | ozgon
# City not found. Skipping...
# Processing Record 29 of Set 4 | garoua
# Processing Record 30 of Set 4 | bilibino
# Processing Record 31 of Set 4 | luderitz
# Processing Record 32 of Set 4 | iqaluit
# Processing Record 33 of Set 4 | port hardy
# Processing Record 34 of Set 4 | birzai
# Processing Record 35 of Set 4 | chepareria
# Processing Record 36 of Set 4 | cherskiy
# Processing Record 37 of Set 4 | cape town
# Processing Record 38 of Set 4 | tabou
# Processing Record 39 of Set 4 | meybod
# Processing Record 40 of Set 4 | apastovo
# Processing Record 41 of Set 4 | cockburn town
# Processing Record 42 of Set 4 | diego de almagro
# Processing Record 43 of Set 4 | hilo
# Processing Record 44 of Set 4 | nanyamba
# Processing Record 45 of Set 4 | mikuni
# Processing Record 46 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 4 | sao joao da barra
# Processing Record 48 of Set 4 | lorengau
# Processing Record 49 of Set 4 | kaitangata
# Processing Record 50 of Set 4 | eshowe
# Processing Record 1 of Set 5 | tuktoyaktuk
# Processing Record 2 of Set 5 | arroyo
# Processing Record 3 of Set 5 | waingapu
# Processing Record 4 of Set 5 | demmin
# Processing Record 5 of Set 5 | palu
# Processing Record 6 of Set 5 | pochutla
# Processing Record 7 of Set 5 | ancud
# Processing Record 8 of Set 5 | athabasca
# Processing Record 9 of Set 5 | oranjemund
# Processing Record 10 of Set 5 | kahului
# Processing Record 11 of Set 5 | kombissiri
# Processing Record 12 of Set 5 | kikwit
# Processing Record 13 of Set 5 | abohar
# Processing Record 14 of Set 5 | comodoro rivadavia
# Processing Record 15 of Set 5 | iquique
# Processing Record 16 of Set 5 | cabo san lucas
# Processing Record 17 of Set 5 | rutana
# Processing Record 18 of Set 5 | meulaboh
# Processing Record 19 of Set 5 | molina
# Processing Record 20 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 21 of Set 5 | lebu
# Processing Record 22 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 5 | quatre cocos
# Processing Record 24 of Set 5 | hasaki
# Processing Record 25 of Set 5 | bluff
# Processing Record 26 of Set 5 | kaeo
# Processing Record 27 of Set 5 | buala
# Processing Record 28 of Set 5 | takoradi
# Processing Record 29 of Set 5 | maine-soroa
# Processing Record 30 of Set 5 | broome
# Processing Record 31 of Set 5 | inirida
# Processing Record 32 of Set 5 | ushtobe
# Processing Record 33 of Set 5 | taft
# Processing Record 34 of Set 5 | belaya gora
# Processing Record 35 of Set 5 | lavrentiya
# Processing Record 36 of Set 5 | beyneu
# Processing Record 37 of Set 5 | ginda
# Processing Record 38 of Set 5 | bainbridge
# Processing Record 39 of Set 5 | taoudenni
# Processing Record 40 of Set 5 | chokurdakh
# Processing Record 41 of Set 5 | nautla
# Processing Record 42 of Set 5 | sandpoint
# Processing Record 43 of Set 5 | porto novo
# Processing Record 44 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 5 | buin
# Processing Record 46 of Set 5 | kirakira
# Processing Record 47 of Set 5 | clyde river
# Processing Record 48 of Set 5 | lafia
# Processing Record 49 of Set 5 | victor harbor
# Processing Record 50 of Set 5 | talnakh
# Processing Record 1 of Set 6 | den helder
# Processing Record 2 of Set 6 | sorland
# Processing Record 3 of Set 6 | natal
# Processing Record 4 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 5 of Set 6 | bambous virieux
# Processing Record 6 of Set 6 | ternate
# Processing Record 7 of Set 6 | beloha
# Processing Record 8 of Set 6 | carndonagh
# Processing Record 9 of Set 6 | akyab
# Processing Record 10 of Set 6 | mount gambier
# Processing Record 11 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 12 of Set 6 | novopokrovka
# Processing Record 13 of Set 6 | constitucion
# Processing Record 14 of Set 6 | masuda
# Processing Record 15 of Set 6 | birao
# Processing Record 16 of Set 6 | maun
# Processing Record 17 of Set 6 | afzalpur
# Processing Record 18 of Set 6 | tuatapere
# Processing Record 19 of Set 6 | chapais
# Processing Record 20 of Set 6 | nadvoitsy
# Processing Record 21 of Set 6 | ketchikan
# Processing Record 22 of Set 6 | kruisfontein
# Processing Record 23 of Set 6 | te anau
# Processing Record 24 of Set 6 | mahebourg
# Processing Record 25 of Set 6 | iralaya
# Processing Record 26 of Set 6 | saint anthony
# Processing Record 27 of Set 6 | marawi
# Processing Record 28 of Set 6 | bengkulu
# Processing Record 29 of Set 6 | chimore
# Processing Record 30 of Set 6 | ishigaki
# Processing Record 31 of Set 6 | axim
# Processing Record 32 of Set 6 | naze
# Processing Record 33 of Set 6 | port keats
# Processing Record 34 of Set 6 | ilulissat
# Processing Record 35 of Set 6 | farafenni
# Processing Record 36 of Set 6 | ponta pora
# Processing Record 37 of Set 6 | ingham
# Processing Record 38 of Set 6 | lompoc
# Processing Record 39 of Set 6 | khani
# Processing Record 40 of Set 6 | pacific grove
# Processing Record 41 of Set 6 | martapura
# Processing Record 42 of Set 6 | alofi
# Processing Record 43 of Set 6 | kodiak
# Processing Record 44 of Set 6 | verkh-chebula
# Processing Record 45 of Set 6 | ozernovskiy
# Processing Record 46 of Set 6 | cidreira
# Processing Record 47 of Set 6 | clonakilty
# Processing Record 48 of Set 6 | darhan
# Processing Record 49 of Set 6 | virginia beach
# Processing Record 50 of Set 6 | arlit
# Processing Record 1 of Set 7 | locri
# Processing Record 2 of Set 7 | namibe
# Processing Record 3 of Set 7 | brewster
# Processing Record 4 of Set 7 | tidore
# City not found. Skipping...
# Processing Record 5 of Set 7 | karanja
# Processing Record 6 of Set 7 | chalmette
# Processing Record 7 of Set 7 | buariki
# City not found. Skipping...
# Processing Record 8 of Set 7 | katsuura
# Processing Record 9 of Set 7 | toora-khem
# Processing Record 10 of Set 7 | synya
# Processing Record 11 of Set 7 | haines junction
# Processing Record 12 of Set 7 | bubaque
# Processing Record 13 of Set 7 | teguise
# Processing Record 14 of Set 7 | paita
# Processing Record 15 of Set 7 | praia
# Processing Record 16 of Set 7 | amga
# Processing Record 17 of Set 7 | kollumerland
# City not found. Skipping...
# Processing Record 18 of Set 7 | derzhavinsk
# Processing Record 19 of Set 7 | springbok
# Processing Record 20 of Set 7 | camacha
# Processing Record 21 of Set 7 | victoria
# Processing Record 22 of Set 7 | sabang
# Processing Record 23 of Set 7 | calderitas
# Processing Record 24 of Set 7 | la uribe
# City not found. Skipping...
# Processing Record 25 of Set 7 | grand-santi
# Processing Record 26 of Set 7 | sorong
# Processing Record 27 of Set 7 | kaspiysk
# Processing Record 28 of Set 7 | waipawa
# Processing Record 29 of Set 7 | berezovyy
# Processing Record 30 of Set 7 | kiszombor
# Processing Record 31 of Set 7 | lagos
# Processing Record 32 of Set 7 | broken hill
# Processing Record 33 of Set 7 | batken
# Processing Record 34 of Set 7 | verkhoyansk
# Processing Record 35 of Set 7 | plettenberg bay
# Processing Record 36 of Set 7 | paka
# Processing Record 37 of Set 7 | wanning
# Processing Record 38 of Set 7 | ledyard
# Processing Record 39 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 40 of Set 7 | dakoro
# Processing Record 41 of Set 7 | port macquarie
# Processing Record 42 of Set 7 | santo domingo
# Processing Record 43 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 44 of Set 7 | sao gabriel da cachoeira
# Processing Record 45 of Set 7 | skibbereen
# Processing Record 46 of Set 7 | salalah
# Processing Record 47 of Set 7 | cayhagan
# Processing Record 48 of Set 7 | tazovskiy
# Processing Record 49 of Set 7 | port-gentil
# Processing Record 50 of Set 7 | gryazovets
# Processing Record 1 of Set 8 | vallenar
# Processing Record 2 of Set 8 | pindiga
# Processing Record 3 of Set 8 | ahuimanu
# Processing Record 4 of Set 8 | wuda
# Processing Record 5 of Set 8 | katsiveli
# City not found. Skipping...
# Processing Record 6 of Set 8 | ponta delgada
# Processing Record 7 of Set 8 | zhigansk
# Processing Record 8 of Set 8 | arraial do cabo
# Processing Record 9 of Set 8 | shimanovsk
# Processing Record 10 of Set 8 | muyezerskiy
# Processing Record 11 of Set 8 | sechura
# Processing Record 12 of Set 8 | rosario
# Processing Record 13 of Set 8 | kidodi
# Processing Record 14 of Set 8 | upernavik
# Processing Record 15 of Set 8 | puerto suarez
# Processing Record 16 of Set 8 | sivaki
# Processing Record 17 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 18 of Set 8 | cayenne
# Processing Record 19 of Set 8 | mabaruma
# Processing Record 20 of Set 8 | port hedland
# Processing Record 21 of Set 8 | krasnyy chikoy
# Processing Record 22 of Set 8 | kerouane
# Processing Record 23 of Set 8 | lebyazhye
# Processing Record 24 of Set 8 | santa marinella
# Processing Record 25 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 8 | rawson
# Processing Record 27 of Set 8 | nedjo
# Processing Record 28 of Set 8 | oistins
# Processing Record 29 of Set 8 | dwarka
# Processing Record 30 of Set 8 | damara
# Processing Record 31 of Set 8 | gat
# Processing Record 32 of Set 8 | kitaibaraki
# Processing Record 33 of Set 8 | beringovskiy
# Processing Record 34 of Set 8 | flin flon
# Processing Record 35 of Set 8 | bathsheba
# Processing Record 36 of Set 8 | sedona
# Processing Record 37 of Set 8 | yanliang
# Processing Record 38 of Set 8 | pyapon
# Processing Record 39 of Set 8 | lixourion
# Processing Record 40 of Set 8 | antofagasta
# Processing Record 41 of Set 8 | ambilobe
# Processing Record 42 of Set 8 | acaponeta
# Processing Record 43 of Set 8 | sumbawa
# City not found. Skipping...
# Processing Record 44 of Set 8 | gwadar
# Processing Record 45 of Set 8 | imbituba
# Processing Record 46 of Set 8 | boyolali
# Processing Record 47 of Set 8 | hambantota
# Processing Record 48 of Set 8 | tigil
# Processing Record 49 of Set 8 | nagato
# Processing Record 50 of Set 8 | saint-pierre
# Processing Record 1 of Set 9 | saint-pascal
# City not found. Skipping...
# Processing Record 2 of Set 9 | yanam
# Processing Record 3 of Set 9 | pak phanang
# Processing Record 4 of Set 9 | mangan
# Processing Record 5 of Set 9 | gazojak
# Processing Record 6 of Set 9 | praia da vitoria
# Processing Record 7 of Set 9 | sri aman
# Processing Record 8 of Set 9 | goderich
# Processing Record 9 of Set 9 | fengrun
# Processing Record 10 of Set 9 | tkibuli
# Processing Record 11 of Set 9 | acajutla
# Processing Record 12 of Set 9 | ozu
# Processing Record 13 of Set 9 | bustonkala
# City not found. Skipping...
# Processing Record 14 of Set 9 | taburi
# City not found. Skipping...
# Processing Record 15 of Set 9 | touros
# Processing Record 16 of Set 9 | komsomolskiy
# Processing Record 17 of Set 9 | umm lajj
# Processing Record 18 of Set 9 | winnemucca
# Processing Record 19 of Set 9 | tsabong
# Processing Record 20 of Set 9 | uwayl
# City not found. Skipping...
# Processing Record 21 of Set 9 | kabalo
# Processing Record 22 of Set 9 | banda aceh
# Processing Record 23 of Set 9 | azimur
# City not found. Skipping...
# Processing Record 24 of Set 9 | bitung
# Processing Record 25 of Set 9 | kanalia
# Processing Record 26 of Set 9 | nortelandia
# Processing Record 27 of Set 9 | algiers
# Processing Record 28 of Set 9 | fiditi
# Processing Record 29 of Set 9 | saint-die
# City not found. Skipping...
# Processing Record 30 of Set 9 | los llanos de aridane
# Processing Record 31 of Set 9 | nuuk
# Processing Record 32 of Set 9 | leua
# Processing Record 33 of Set 9 | tawang
# Processing Record 34 of Set 9 | port-cartier
# Processing Record 35 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 9 | konstantinovka
# Processing Record 37 of Set 9 | stornoway
# Processing Record 38 of Set 9 | hay river
# Processing Record 39 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 40 of Set 9 | altamont
# Processing Record 41 of Set 9 | vardo
# Processing Record 42 of Set 9 | boa vista
# Processing Record 43 of Set 9 | hofn
# Processing Record 44 of Set 9 | chulym
# Processing Record 45 of Set 9 | dunmore east
# Processing Record 46 of Set 9 | parnarama
# Processing Record 47 of Set 9 | sur
# Processing Record 48 of Set 9 | gazanjyk
# Processing Record 49 of Set 9 | tambaram
# Processing Record 50 of Set 9 | dalian
# Processing Record 1 of Set 10 | tumbes
# Processing Record 2 of Set 10 | vanavara
# Processing Record 3 of Set 10 | namatanai
# Processing Record 4 of Set 10 | paysandu
# Processing Record 5 of Set 10 | marystown
# Processing Record 6 of Set 10 | la ronge
# Processing Record 7 of Set 10 | zhangjiakou
# Processing Record 8 of Set 10 | jaipur
# Processing Record 9 of Set 10 | andilamena
# Processing Record 10 of Set 10 | leningradskiy
# Processing Record 11 of Set 10 | bismarck
# Processing Record 12 of Set 10 | kurikka
# Processing Record 13 of Set 10 | faya
# Processing Record 14 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 10 | saint pete beach
# Processing Record 16 of Set 10 | zhongshu
# Processing Record 17 of Set 10 | gaoual
# Processing Record 18 of Set 10 | tautira
# Processing Record 19 of Set 10 | balakhninskiy
# Processing Record 20 of Set 10 | harper
# Processing Record 21 of Set 10 | shakiso
# Processing Record 22 of Set 10 | huarmey
# Processing Record 23 of Set 10 | shimoda
# Processing Record 24 of Set 10 | adelaide
# Processing Record 25 of Set 10 | nantucket
# Processing Record 26 of Set 10 | kaabong
# Processing Record 27 of Set 10 | semnan
# Processing Record 28 of Set 10 | dongsheng
# Processing Record 29 of Set 10 | abu samrah
# Processing Record 30 of Set 10 | ituni
# City not found. Skipping...
# Processing Record 31 of Set 10 | yalutorovsk
# Processing Record 32 of Set 10 | okha
# Processing Record 33 of Set 10 | healdsburg
# Processing Record 34 of Set 10 | lambari
# Processing Record 35 of Set 10 | kalmunai
# Processing Record 36 of Set 10 | weimar
# Processing Record 37 of Set 10 | richland
# Processing Record 38 of Set 10 | hami
# Processing Record 39 of Set 10 | promissao
# Processing Record 40 of Set 10 | morro bay
# Processing Record 41 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 10 | biak
# Processing Record 43 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 10 | margate
# Processing Record 45 of Set 10 | klaksvik
# Processing Record 46 of Set 10 | salta
# Processing Record 47 of Set 10 | madang
# Processing Record 48 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 10 | henties bay
# Processing Record 50 of Set 10 | champerico
# Processing Record 1 of Set 11 | sokolo
# Processing Record 2 of Set 11 | lugovoy
# Processing Record 3 of Set 11 | aswan
# Processing Record 4 of Set 11 | miami
# Processing Record 5 of Set 11 | borogontsy
# Processing Record 6 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 7 of Set 11 | semme
# Processing Record 8 of Set 11 | miri
# Processing Record 9 of Set 11 | quirinopolis
# Processing Record 10 of Set 11 | devonport
# Processing Record 11 of Set 11 | sembe
# Processing Record 12 of Set 11 | safford
# Processing Record 13 of Set 11 | tak
# Processing Record 14 of Set 11 | aksu
# Processing Record 15 of Set 11 | vylgort
# City not found. Skipping...
# Processing Record 16 of Set 11 | yongan
# Processing Record 17 of Set 11 | buncrana
# Processing Record 18 of Set 11 | abbeville
# Processing Record 19 of Set 11 | kiama
# Processing Record 20 of Set 11 | haflong
# Processing Record 21 of Set 11 | kendari
# Processing Record 22 of Set 11 | saint-augustin
# Processing Record 23 of Set 11 | huazhou
# Processing Record 24 of Set 11 | mirabad
# Processing Record 25 of Set 11 | santa elena
# Processing Record 26 of Set 11 | vredendal
# Processing Record 27 of Set 11 | yagodnoye
# Processing Record 28 of Set 11 | srivardhan
# Processing Record 29 of Set 11 | codrington
# Processing Record 30 of Set 11 | ravar
# Processing Record 31 of Set 11 | sao filipe
# Processing Record 32 of Set 11 | vestmanna
# Processing Record 33 of Set 11 | mozarlandia
# Processing Record 34 of Set 11 | san jeronimo
# Processing Record 35 of Set 11 | burias
# Processing Record 36 of Set 11 | kununurra
# Processing Record 37 of Set 11 | terra santa
# Processing Record 38 of Set 11 | zheleznodorozhnyy
# Processing Record 39 of Set 11 | yulara
# Processing Record 40 of Set 11 | mporokoso
# Processing Record 41 of Set 11 | muravlenko
# Processing Record 42 of Set 11 | khilok
# Processing Record 43 of Set 11 | svetlyy
# Processing Record 44 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 45 of Set 11 | peniche
# Processing Record 46 of Set 11 | salinopolis
# Processing Record 47 of Set 11 | beckley
# Processing Record 48 of Set 11 | odweyne
# Processing Record 49 of Set 11 | erenhot
# Processing Record 50 of Set 11 | lodwar
# Processing Record 1 of Set 12 | liaozhong
# Processing Record 2 of Set 12 | dunedin
# Processing Record 3 of Set 12 | vila franca do campo
# Processing Record 4 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 5 of Set 12 | shrewsbury
# Processing Record 6 of Set 12 | oakley
# Processing Record 7 of Set 12 | radyvyliv
# Processing Record 8 of Set 12 | santa rita
# Processing Record 9 of Set 12 | falavarjan
# Processing Record 10 of Set 12 | pisco
# Processing Record 11 of Set 12 | arriana
# Processing Record 12 of Set 12 | along
# Processing Record 13 of Set 12 | cairo
# Processing Record 14 of Set 12 | ijaki
# City not found. Skipping...
# Processing Record 15 of Set 12 | kaduqli
# Processing Record 16 of Set 12 | portland
# Processing Record 17 of Set 12 | narsaq
# Processing Record 18 of Set 12 | pelym
# Processing Record 19 of Set 12 | khor
# Processing Record 20 of Set 12 | keizer
# Processing Record 21 of Set 12 | collie
# Processing Record 22 of Set 12 | nishihara
# Processing Record 23 of Set 12 | oktyabrskiy
# Processing Record 24 of Set 12 | walsall
# Processing Record 25 of Set 12 | sretensk
# Processing Record 26 of Set 12 | ramon castilla
# Processing Record 27 of Set 12 | clarence town
# Processing Record 28 of Set 12 | konce
# Processing Record 29 of Set 12 | pangnirtung
# Processing Record 30 of Set 12 | souillac
# Processing Record 31 of Set 12 | rio cuarto
# Processing Record 32 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 33 of Set 12 | namsos
# Processing Record 34 of Set 12 | careiro da varzea
# Processing Record 35 of Set 12 | manhush
# Processing Record 36 of Set 12 | la libertad
# Processing Record 37 of Set 12 | tir pol
# City not found. Skipping...
# Processing Record 38 of Set 12 | kamenka
# Processing Record 39 of Set 12 | maralal
# Processing Record 40 of Set 12 | steamboat springs
# Processing Record 41 of Set 12 | hatta
# Processing Record 42 of Set 12 | bure
# Processing Record 43 of Set 12 | husavik
# Processing Record 44 of Set 12 | xuddur
# Processing Record 45 of Set 12 | florida
# Processing Record 46 of Set 12 | conde
# Processing Record 47 of Set 12 | bethanien
# Processing Record 48 of Set 12 | taraz
# Processing Record 49 of Set 12 | aykhal
# Processing Record 50 of Set 12 | bosanska gradiska
# Processing Record 1 of Set 13 | fort saint john
# City not found. Skipping...
# Processing Record 2 of Set 13 | natchez
# Processing Record 3 of Set 13 | dekar
# Processing Record 4 of Set 13 | higuey
# City not found. Skipping...
# Processing Record 5 of Set 13 | seoul
# Processing Record 6 of Set 13 | coquimbo
# Processing Record 7 of Set 13 | port augusta
# Processing Record 8 of Set 13 | camacupa
# Processing Record 9 of Set 13 | upington
# Processing Record 10 of Set 13 | salamiyah
# Processing Record 11 of Set 13 | cravo norte
# Processing Record 12 of Set 13 | aksarka
# Processing Record 13 of Set 13 | kyzyl-suu
# Processing Record 14 of Set 13 | puerto penasco
# Processing Record 15 of Set 13 | vestmannaeyjar
# Processing Record 16 of Set 13 | havoysund
# Processing Record 17 of Set 13 | samarai
# Processing Record 18 of Set 13 | aquiraz
# Processing Record 19 of Set 13 | puerto escondido
# Processing Record 20 of Set 13 | altamira
# Processing Record 21 of Set 13 | dusetos
# Processing Record 22 of Set 13 | baruun-urt
# Processing Record 23 of Set 13 | haimen
# Processing Record 24 of Set 13 | halifax
# Processing Record 25 of Set 13 | laguna
# Processing Record 26 of Set 13 | gamboma
# Processing Record 27 of Set 13 | idrinskoye
# Processing Record 28 of Set 13 | khakhea
# Processing Record 29 of Set 13 | tabas
# Processing Record 30 of Set 13 | chernyshevskiy
# Processing Record 31 of Set 13 | kinkala
# Processing Record 32 of Set 13 | waddan
# Processing Record 33 of Set 13 | virden
# Processing Record 34 of Set 13 | geraldton
# Processing Record 35 of Set 13 | anse-bertrand
# Processing Record 36 of Set 13 | maturin
# Processing Record 37 of Set 13 | medicine hat
# Processing Record 38 of Set 13 | aurora
# Processing Record 39 of Set 13 | anadyr
# Processing Record 40 of Set 13 | kawalu
# Processing Record 41 of Set 13 | druzhba
# Processing Record 42 of Set 13 | jesus de otoro
# Processing Record 43 of Set 13 | mendi
# Processing Record 44 of Set 13 | zhanakorgan
# Processing Record 45 of Set 13 | velasco ibarra
# Processing Record 46 of Set 13 | frontera
# Processing Record 47 of Set 13 | havelock
# Processing Record 48 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 13 | palm desert
# Processing Record 50 of Set 13 | saquena
# Processing Record 1 of Set 14 | korla
# Processing Record 2 of Set 14 | aklavik
# Processing Record 3 of Set 14 | ekhabi
# Processing Record 4 of Set 14 | ardesen
# Processing Record 5 of Set 14 | omboue
# Processing Record 6 of Set 14 | northam
# Processing Record 7 of Set 14 | rudbar
# Processing Record 8 of Set 14 | raudeberg
# Processing Record 9 of Set 14 | myitkyina
# Processing Record 10 of Set 14 | tromso
# Processing Record 11 of Set 14 | saint-louis
# Processing Record 12 of Set 14 | kungurtug
# Processing Record 13 of Set 14 | aksha
# Processing Record 14 of Set 14 | sarangani
# Processing Record 15 of Set 14 | ballina
# Processing Record 16 of Set 14 | normandin
# Processing Record 17 of Set 14 | malmesbury
# Processing Record 18 of Set 14 | richards bay
# Processing Record 19 of Set 14 | pendleton
# Processing Record 20 of Set 14 | fengcheng
# Processing Record 21 of Set 14 | nome
# Processing Record 22 of Set 14 | mill valley
# Processing Record 23 of Set 14 | kosh-agach
# Processing Record 24 of Set 14 | baykit
# Processing Record 25 of Set 14 | moche
# Processing Record 26 of Set 14 | mapiripan
# Processing Record 27 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 28 of Set 14 | san quintin
# Processing Record 29 of Set 14 | karpuninskiy
# City not found. Skipping...
# Processing Record 30 of Set 14 | baniyas
# Processing Record 31 of Set 14 | cafelandia
# Processing Record 32 of Set 14 | alyangula
# Processing Record 33 of Set 14 | mulege
# Processing Record 34 of Set 14 | hilton head island
# Processing Record 35 of Set 14 | tucuman
# Processing Record 36 of Set 14 | notre-dame-du-lac
# Processing Record 37 of Set 14 | muroto
# Processing Record 38 of Set 14 | walvis bay
# Processing Record 39 of Set 14 | valparaiso
# Processing Record 40 of Set 14 | baghmara
# Processing Record 41 of Set 14 | bidar
# Processing Record 42 of Set 14 | dingle
# Processing Record 43 of Set 14 | sibolga
# Processing Record 44 of Set 14 | deer lake
# Processing Record 45 of Set 14 | filingue
# Processing Record 46 of Set 14 | baloda bazar
# Processing Record 47 of Set 14 | bagan
# Processing Record 48 of Set 14 | usinsk
# Processing Record 49 of Set 14 | bahia blanca
# Processing Record 50 of Set 14 | general pico
# Processing Record 1 of Set 15 | jalu
# Processing Record 2 of Set 15 | trincomalee
# Processing Record 3 of Set 15 | uvarovka
# Processing Record 4 of Set 15 | alta floresta
# Processing Record 5 of Set 15 | araouane
# Processing Record 6 of Set 15 | fukuma
# Processing Record 7 of Set 15 | dutse
# Processing Record 8 of Set 15 | los algarrobos
# Processing Record 9 of Set 15 | las choapas
# Processing Record 10 of Set 15 | sfantu gheorghe
# Processing Record 11 of Set 15 | kati
# Processing Record 12 of Set 15 | kloulklubed
# Processing Record 13 of Set 15 | inverell
# Processing Record 14 of Set 15 | baie-comeau
# Processing Record 15 of Set 15 | san vicente
# Processing Record 16 of Set 15 | srandakan
# Processing Record 17 of Set 15 | the valley
# Processing Record 18 of Set 15 | yantal
# Processing Record 19 of Set 15 | ayan
# Processing Record 20 of Set 15 | sept-iles
# Processing Record 21 of Set 15 | talara
# Processing Record 22 of Set 15 | newport
# Processing Record 23 of Set 15 | hovd
# Processing Record 24 of Set 15 | kolobrzeg
# Processing Record 25 of Set 15 | venado tuerto
# Processing Record 26 of Set 15 | bumba
# Processing Record 27 of Set 15 | sol-iletsk
# Processing Record 28 of Set 15 | singaparna
# Processing Record 29 of Set 15 | nemuro
# Processing Record 30 of Set 15 | kitimat
# Processing Record 31 of Set 15 | kachug
# Processing Record 32 of Set 15 | grindavik
# Processing Record 33 of Set 15 | mikumi
# Processing Record 34 of Set 15 | mandera
# Processing Record 35 of Set 15 | kupang
# Processing Record 36 of Set 15 | hammerfest
# Processing Record 37 of Set 15 | presidente prudente
# Processing Record 38 of Set 15 | biltine
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Port Lincoln      AU -34.7333  135.8667     64.74        74         100
# 1        Zlobin      HR  45.2924   14.6541     42.10        67          20
# 2          Tura      IN  25.5198   90.2201     67.50        66           0
# 3     Byron Bay      AU -28.6500  153.6167     77.70        75          33
# 4  Punta Arenas      CL -53.1500  -70.9167     42.91        56          75
# 5       Ushuaia      AR -54.8000  -68.3000     38.86        70          75
# 6   East London      ZA -33.0153   27.9116     66.18        86         100
# 7    Georgetown      MY   5.4112  100.3354     82.33        90          20
# 8          Elko      US  41.0002 -115.5012     36.64        46           0
# 9      Saldanha      ZA -33.0117   17.9442     60.84        83           0
#
#    Wind Speed Current Description
# 0       12.19       moderate rain
# 1       20.71          few clouds
# 2        1.83           clear sky
# 3        9.35    scattered clouds
# 4        4.61       broken clouds
# 5       18.41       broken clouds
# 6       19.33          light rain
# 7        1.01          few clouds
# 8        7.00           clear sky
# 9       13.47           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
